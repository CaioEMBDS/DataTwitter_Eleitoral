# %% [markdown]
# <a href="https://colab.research.google.com/github/CaioEMBDS/DataTwitter_Eleitoral/blob/main/Etapa_4_An%C3%A1lise_de_Sentimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Libs

# %%
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.7/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2022.6.15)

# %%
import pandas as pd

#Expressões Regulares
import re

#Para Visualização
import matplotlib.pyplot as plt

#Para análise de sentimentos
import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ##DataFrame

# %%
df_sentimento = pd.read_csv('/content/Etapa 3.csv')

# %%
df_sentimento
# Out:
#                      Data_Hora              IdTweet  \
# 0    2022-08-01 12:15:12+00:00  1554078292004577283
# 1    2022-08-01 12:15:12+00:00  1554078289316253697
# 2    2022-08-01 12:15:12+00:00  1554078289148493824
# 3    2022-08-01 12:15:10+00:00  1554078280223006726
# 4    2022-08-01 12:15:08+00:00  1554078275269529602
# ..                         ...                  ...
# 148  2022-08-01 12:16:35+00:00  1554078640173993984
# 149  2022-08-01 12:16:34+00:00  1554078633110786049
# 150  2022-08-01 12:16:33+00:00  1554078631391010824
# 151  2022-08-01 12:16:26+00:00  1554078599447298049
# 152  2022-08-01 12:16:13+00:00  1554078545944760320
#
#                                                  Tweet Candidato  \
# 0    Ganni Lula Women's red patent leather slip on ...      Lula
# 1    Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2    @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3    @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# 4    Bom dia meu amigo Humber tô Costa eu não conco...      Lula
# ..                                                 ...       ...
# 148  @cirogomes @CartunistaT E vc é o mestre dos ma...      Ciro
# 149  @VanAzevedo1 @BrazilFight Ele é  louco. Jaja e...      Ciro
# 150  @renato_abreu88 @cirogomes Pra gente não faz d...      Ciro
# 151  @cirogomes @CartunistaT Se eu fosse cirista eu...      Ciro
# 152  Impossível discordar de Ciro Gomes nessa. Infe...      Ciro
#
#                                            Tweet_limpo
# 0    ganni lula women's red patent leather slip on ...
# 1    bom para todos eleitores do lula🌹“que a felici...
# 2                               avisa a miriam leitão
# 3     datafolha: 100% dos brasileiros acreditam que...
# 4    bom dia meu amigo humber tô costa eu não conco...
# ..                                                 ...
# 148    e vc é o mestre dos magos, que não queria de...
# 149    ele é  louco. jaja elogia o pinguço.  tudo d...
# 150    pra gente não faz diferença!! estamos só esp...
# 151    se eu fosse cirista eu já tinha me enterrado...
# 152  impossível discordar de ciro gomes nessa. infe...
#
# [153 rows x 5 columns]

# %% [markdown]
# ##Aplicando Função de Análise de Sentimentos

# %%
analisador_de_texto = SentimentIntensityAnalyzer()

# %%
df_sentimento['Sentimentos'] = df_sentimento['Tweet_limpo'].apply(lambda i: analisador_de_texto.polarity_scores(' '.join(re.findall(r'\w+', i.lower()))))

# %%
df_sentimento.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-08-01 12:15:12+00:00  1554078292004577283
# 1  2022-08-01 12:15:12+00:00  1554078289316253697
# 2  2022-08-01 12:15:12+00:00  1554078289148493824
# 3  2022-08-01 12:15:10+00:00  1554078280223006726
# 4  2022-08-01 12:15:08+00:00  1554078275269529602
#
#                                                Tweet Candidato  \
# 0  Ganni Lula Women's red patent leather slip on ...      Lula
# 1  Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2  @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3  @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# 4  Bom dia meu amigo Humber tô Costa eu não conco...      Lula
#
#                                          Tweet_limpo  \
# 0  ganni lula women's red patent leather slip on ...
# 1  bom para todos eleitores do lula🌹“que a felici...
# 2                             avisa a miriam leitão
# 3   datafolha: 100% dos brasileiros acreditam que...
# 4  bom dia meu amigo humber tô costa eu não conco...
#
#                                          Sentimentos
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %%
df_sentimento.Sentimentos
# Out:
# 0      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#                              ...
# 148    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 149    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 150    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 151    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 152    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# Name: Sentimentos, Length: 153, dtype: object

# %% [markdown]
# ##Preciso retirar da estrutura de dicionários, e pegar apenas os valores e retirar as chaves com Expressões Regulares:
# >Criar 4 colunas:
# >>Uma com valor do negativo
#
# >>uma com valor do neutro
#
# >>Uma do valor positivo
#
# >>uma coluna final com o resultado

# %%
df_sentimento['Positivo'] = df_sentimento['Sentimentos'].apply(lambda i: i['pos'])
df_sentimento.loc[df_sentimento['Positivo'] > 0] #funcionou
# Out:
#                      Data_Hora              IdTweet  \
# 24   2022-08-01 12:14:54+00:00  1554078213172781056
# 76   2022-08-01 12:20:54+00:00  1554079723747155971
# 94   2022-08-01 12:20:29+00:00  1554079621406199809
# 111  2022-08-01 12:20:31+00:00  1554079627873845249
# 115  2022-08-01 12:19:53+00:00  1554079470889435140
# 120  2022-08-01 12:19:25+00:00  1554079351959949312
# 147  2022-08-01 12:16:37+00:00  1554078648826843136
#
#                                                  Tweet  Candidato  \
# 24   Bom dia, geral . \nHoje é dia de compartilhar,...       Lula
# 76   @Kim_Galo1989 @RomeuZema Ok. O Temer decidiu. ...  Bolsonaro
# 94   @jairbolsonaro É isso ai meu Presidente, quand...  Bolsonaro
# 111  @cirogomes @CartunistaT O mais legal é ver os ...       Ciro
# 115  @camarq @cirogomes na Amazon tem.. https://t.c...       Ciro
# 120  @cirogomes @Debinha7 @CopaAmerica 🇧🇷✊😀🌹 #CiroP...       Ciro
# 147  @oBarbudinho @cirogomes "Muito bom seu stand u...       Ciro
#
#                                            Tweet_limpo  \
# 24   bom dia, geral . hoje é dia de compartilhar, c...
# 76     ok. o temer decidiu. o bolsonaro decidiu man...
# 94    é isso ai meu presidente, quando que entra em...
# 111    o mais legal é ver os petistas latindo nos c...
# 115                                   na amazon tem..
# 120     🇧🇷✊😀🌹  pra reindustrializar e empregar (&gt...
# 147                    "muito bom seu stand up comedy"
#
#                                            Sentimentos  Positivo
# 24   {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'comp...     0.041
# 76   {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'comp...     0.216
# 94   {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...     0.110
# 111  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...     0.143
# 115  {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'comp...     0.459
# 120  {'neg': 0.0, 'neu': 0.388, 'pos': 0.612, 'comp...     0.612
# 147  {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'comp...     0.333

# %%
df_sentimento['Neutro'] = df_sentimento['Sentimentos'].apply(lambda i: i['neu'])
df_sentimento.loc[df_sentimento['Neutro'] > 0]
# Out:
#                      Data_Hora              IdTweet  \
# 0    2022-08-01 12:15:12+00:00  1554078292004577283
# 1    2022-08-01 12:15:12+00:00  1554078289316253697
# 2    2022-08-01 12:15:12+00:00  1554078289148493824
# 3    2022-08-01 12:15:10+00:00  1554078280223006726
# 4    2022-08-01 12:15:08+00:00  1554078275269529602
# ..                         ...                  ...
# 148  2022-08-01 12:16:35+00:00  1554078640173993984
# 149  2022-08-01 12:16:34+00:00  1554078633110786049
# 150  2022-08-01 12:16:33+00:00  1554078631391010824
# 151  2022-08-01 12:16:26+00:00  1554078599447298049
# 152  2022-08-01 12:16:13+00:00  1554078545944760320
#
#                                                  Tweet Candidato  \
# 0    Ganni Lula Women's red patent leather slip on ...      Lula
# 1    Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2    @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3    @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# 4    Bom dia meu amigo Humber tô Costa eu não conco...      Lula
# ..                                                 ...       ...
# 148  @cirogomes @CartunistaT E vc é o mestre dos ma...      Ciro
# 149  @VanAzevedo1 @BrazilFight Ele é  louco. Jaja e...      Ciro
# 150  @renato_abreu88 @cirogomes Pra gente não faz d...      Ciro
# 151  @cirogomes @CartunistaT Se eu fosse cirista eu...      Ciro
# 152  Impossível discordar de Ciro Gomes nessa. Infe...      Ciro
#
#                                            Tweet_limpo  \
# 0    ganni lula women's red patent leather slip on ...
# 1    bom para todos eleitores do lula🌹“que a felici...
# 2                               avisa a miriam leitão
# 3     datafolha: 100% dos brasileiros acreditam que...
# 4    bom dia meu amigo humber tô costa eu não conco...
# ..                                                 ...
# 148    e vc é o mestre dos magos, que não queria de...
# 149    ele é  louco. jaja elogia o pinguço.  tudo d...
# 150    pra gente não faz diferença!! estamos só esp...
# 151    se eu fosse cirista eu já tinha me enterrado...
# 152  impossível discordar de ciro gomes nessa. infe...
#
#                                            Sentimentos  Positivo  Neutro
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 1    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 4    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# ..                                                 ...       ...     ...
# 148  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 149  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 150  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 151  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 152  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
#
# [146 rows x 8 columns]

# %%
df_sentimento['Negativo'] = df_sentimento['Sentimentos'].apply(lambda i: i['neg'])
df_sentimento.loc[df_sentimento['Negativo'] > 0]
# Out:
#                      Data_Hora              IdTweet  \
# 8    2022-08-01 12:15:05+00:00  1554078261746991106
# 14   2022-08-01 12:14:59+00:00  1554078236426092545
# 20   2022-08-01 12:14:56+00:00  1554078222278688768
# 28   2022-08-01 12:14:51+00:00  1554078202187943936
# 52   2022-08-01 12:21:16+00:00  1554079817435430912
# 59   2022-08-01 12:21:11+00:00  1554079798074417157
# 61   2022-08-01 12:21:11+00:00  1554079794807054337
# 65   2022-08-01 12:21:08+00:00  1554079781683093506
# 73   2022-08-01 12:20:58+00:00  1554079743846350851
# 74   2022-08-01 12:20:56+00:00  1554079731515068418
# 75   2022-08-01 12:20:55+00:00  1554079729237491713
# 78   2022-08-01 12:20:51+00:00  1554079711529209857
# 86   2022-08-01 12:20:38+00:00  1554079659951792135
# 93   2022-08-01 12:20:31+00:00  1554079627114696704
# 100  2022-08-01 12:20:24+00:00  1554079597700042753
# 101  2022-08-01 12:20:23+00:00  1554079594814259206
# 106  2022-08-01 12:20:54+00:00  1554079723311042561
# 108  2022-08-01 12:20:48+00:00  1554079701039300608
# 121  2022-08-01 12:19:25+00:00  1554079350315794432
# 123  2022-08-01 12:19:14+00:00  1554079307454193667
# 125  2022-08-01 12:18:48+00:00  1554079196179300356
# 127  2022-08-01 12:18:39+00:00  1554079159378497537
# 136  2022-08-01 12:17:56+00:00  1554078979837018113
# 140  2022-08-01 12:17:37+00:00  1554078897511301120
#
#                                                  Tweet  Candidato  \
# 8    @LulaOficial @ricardostuckert Vc foi catador d...       Lula
# 14   @bibonunes1 Heita sei não,seis tão maís desesp...       Lula
# 20   @alfredolimaaaa @LulaOficial @ptbrasil Medicin...       Lula
# 28   @CarolDeToni Bom, ainda bem que não sou cristã...       Lula
# 52   É um 10. Mas defende o Bolsonaro no meio do ro...  Bolsonaro
# 59   @josoarestrue O estelionato eleitoral de Bolso...  Bolsonaro
# 61   @LUBIAAGUIAR_ @AnaPaulaVolei @jairbolsonaro Ve...  Bolsonaro
# 65   @PATRlOTAS Presidente Bolsonaro peça a Interve...  Bolsonaro
# 73   @o_antagonista Bolsonaro no primeiro turno!\nS...  Bolsonaro
# 74   @BernardoMF É mesmo 🤔, o povo nas ruas não mos...  Bolsonaro
# 75   @AlexandreKunz4 @Rdebusa Estamos no caminho ce...  Bolsonaro
# 78   @fabiolopesjr2 @auroracadela a pessoa que não ...  Bolsonaro
# 86   Bolsonaro é rei das  FAKE NEWS https://t.co/25...  Bolsonaro
# 93   Fora Bolsonaro Anti Bolsonaro \nBolsonaro A Ca...  Bolsonaro
# 100  @VEJA Bolsonaro no primeiro turno!\nSó isso in...  Bolsonaro
# 101  @mendlowicz Extrema direita no Brasil só tem u...  Bolsonaro
# 106  @gisasouzza @cirogomes Não jogue sujo você! Co...       Ciro
# 108  @ViniciusMach4d0 @cirogomes O único legado do ...       Ciro
# 121  @tatifarah Mais um motivo para colocar @cirogo...       Ciro
# 123  @unatalie @cirogomes Oi @unatalie , tudo bem? ...       Ciro
# 125  Ciro Gomes focalizando no eleitorado do boomer...       Ciro
# 127                 @cirogomes Ciro vai votar no Bozo!       Ciro
# 136  @yehoshuanamaha @nobre_vagabund0 @cirogomes Fr...       Ciro
# 140  @cirogomes É isso mesmo, Ciro. Não tem nenhuma...       Ciro
#
#                                            Tweet_limpo  \
# 8      vc foi catador do dinheiro do povo e quer vo...
# 14    heita sei não,seis tão maís desesperados que ...
# 20      medicina no brasil acabou. tragam os médico...
# 28    bom, ainda bem que não sou cristão, pois vota...
# 52   é um 10. mas defende o bolsonaro no meio do ro...
# 59    o estelionato eleitoral de bolsonaro no preço...
# 61      verdade? mas acho que vi algumas figuras no...
# 65    presidente bolsonaro peça a intervenção feder...
# 73    bolsonaro no primeiro turno!só isso interessa...
# 74    é mesmo 🤔, o povo nas ruas não mostra isso, a...
# 75     estamos no caminho certo, por onde quer que ...
# 78     a pessoa que não consegue reconhecer uma iro...
# 86                bolsonaro é rei das  fake news  via
# 93   fora bolsonaro anti bolsonaro bolsonaro a cabe...
# 100   bolsonaro no primeiro turno!só isso interessa...
# 101   extrema direita no brasil só tem uma, bolsona...
# 106    não jogue sujo você! com o seu joguinho de c...
# 108    o único legado do lula e do pt é a tomada de...
# 121   mais um motivo para colocar  no 2° turno. olh...
# 123    oi  , tudo bem? o lula defende o desmatament...
# 125  ciro gomes focalizando no eleitorado do boomer...
# 127                            ciro vai votar no bozo!
# 136     freud? um charlatão anti-história, só essa ...
# 140   é isso mesmo, ciro. não tem nenhuma lógica co...
#
#                                            Sentimentos  Positivo  Neutro  \
# 8    {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound...       0.0   0.800
# 14   {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...       0.0   0.864
# 20   {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...       0.0   0.855
# 28   {'neg': 0.078, 'neu': 0.922, 'pos': 0.0, 'comp...       0.0   0.922
# 52   {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.0   0.820
# 59   {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...       0.0   0.855
# 61   {'neg': 0.073, 'neu': 0.927, 'pos': 0.0, 'comp...       0.0   0.927
# 65   {'neg': 0.051, 'neu': 0.949, 'pos': 0.0, 'comp...       0.0   0.949
# 73   {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'comp...       0.0   0.732
# 74   {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'comp...       0.0   0.879
# 75   {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.0   0.845
# 78   {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...       0.0   0.855
# 86   {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'comp...       0.0   0.659
# 93   {'neg': 0.15, 'neu': 0.85, 'pos': 0.0, 'compou...       0.0   0.850
# 100  {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'comp...       0.0   0.732
# 101  {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...       0.0   0.855
# 106  {'neg': 0.048, 'neu': 0.952, 'pos': 0.0, 'comp...       0.0   0.952
# 108  {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'comp...       0.0   0.913
# 121  {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'comp...       0.0   0.732
# 123  {'neg': 0.051, 'neu': 0.949, 'pos': 0.0, 'comp...       0.0   0.949
# 125  {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'comp...       0.0   0.891
# 127  {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'comp...       0.0   0.645
# 136  {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'comp...       0.0   0.867
# 140  {'neg': 0.073, 'neu': 0.927, 'pos': 0.0, 'comp...       0.0   0.927
#
#      Negativo
# 8       0.200
# 14      0.136
# 20      0.145
# 28      0.078
# 52      0.180
# 59      0.145
# 61      0.073
# 65      0.051
# 73      0.268
# 74      0.121
# 75      0.155
# 78      0.145
# 86      0.341
# 93      0.150
# 100     0.268
# 101     0.145
# 106     0.048
# 108     0.087
# 121     0.268
# 123     0.051
# 125     0.109
# 127     0.355
# 136     0.133
# 140     0.073

# %%
df_sentimento['Composição'] = df_sentimento['Sentimentos'].apply(lambda i: i['compound'	])
df_sentimento.loc[df_sentimento['Composição']>0]
# Out:
#                      Data_Hora              IdTweet  \
# 24   2022-08-01 12:14:54+00:00  1554078213172781056
# 76   2022-08-01 12:20:54+00:00  1554079723747155971
# 94   2022-08-01 12:20:29+00:00  1554079621406199809
# 111  2022-08-01 12:20:31+00:00  1554079627873845249
# 115  2022-08-01 12:19:53+00:00  1554079470889435140
# 120  2022-08-01 12:19:25+00:00  1554079351959949312
# 147  2022-08-01 12:16:37+00:00  1554078648826843136
#
#                                                  Tweet  Candidato  \
# 24   Bom dia, geral . \nHoje é dia de compartilhar,...       Lula
# 76   @Kim_Galo1989 @RomeuZema Ok. O Temer decidiu. ...  Bolsonaro
# 94   @jairbolsonaro É isso ai meu Presidente, quand...  Bolsonaro
# 111  @cirogomes @CartunistaT O mais legal é ver os ...       Ciro
# 115  @camarq @cirogomes na Amazon tem.. https://t.c...       Ciro
# 120  @cirogomes @Debinha7 @CopaAmerica 🇧🇷✊😀🌹 #CiroP...       Ciro
# 147  @oBarbudinho @cirogomes "Muito bom seu stand u...       Ciro
#
#                                            Tweet_limpo  \
# 24   bom dia, geral . hoje é dia de compartilhar, c...
# 76     ok. o temer decidiu. o bolsonaro decidiu man...
# 94    é isso ai meu presidente, quando que entra em...
# 111    o mais legal é ver os petistas latindo nos c...
# 115                                   na amazon tem..
# 120     🇧🇷✊😀🌹  pra reindustrializar e empregar (&gt...
# 147                    "muito bom seu stand up comedy"
#
#                                            Sentimentos  Positivo  Neutro  \
# 24   {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'comp...     0.041   0.959
# 76   {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'comp...     0.216   0.784
# 94   {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...     0.110   0.890
# 111  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...     0.143   0.857
# 115  {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'comp...     0.459   0.541
# 120  {'neg': 0.0, 'neu': 0.388, 'pos': 0.612, 'comp...     0.612   0.388
# 147  {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'comp...     0.333   0.667
#
#      Negativo  Composição
# 24        0.0      0.1280
# 76        0.0      0.2960
# 94        0.0      0.2732
# 111       0.0      0.1280
# 115       0.0      0.1779
# 120       0.0      0.6486
# 147       0.0      0.3612

# %% [markdown]
# ##Coluna com Resultado Categórico:
# >precisaremos de um loop for com append()

# %%
sentimento = []

# %%
for i in df_sentimento.Composição:
  if i >= 0.05:
    sentimento.append('Positivo')
  elif i <= (-0.05):
    sentimento.append('Neutro')
  else:
    sentimento.append('Negativo')

# %%
sentimento
# Out:
# ['Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Neutro',
#  'Neutro',
#  'Positivo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Neutro',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Positivo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo',
#  'Negativo']

# %%
df_sentimento['Resultado_Sentimento'] = sentimento
df_sentimento
# Out:
#                      Data_Hora              IdTweet  \
# 0    2022-08-01 12:15:12+00:00  1554078292004577283
# 1    2022-08-01 12:15:12+00:00  1554078289316253697
# 2    2022-08-01 12:15:12+00:00  1554078289148493824
# 3    2022-08-01 12:15:10+00:00  1554078280223006726
# 4    2022-08-01 12:15:08+00:00  1554078275269529602
# ..                         ...                  ...
# 148  2022-08-01 12:16:35+00:00  1554078640173993984
# 149  2022-08-01 12:16:34+00:00  1554078633110786049
# 150  2022-08-01 12:16:33+00:00  1554078631391010824
# 151  2022-08-01 12:16:26+00:00  1554078599447298049
# 152  2022-08-01 12:16:13+00:00  1554078545944760320
#
#                                                  Tweet Candidato  \
# 0    Ganni Lula Women's red patent leather slip on ...      Lula
# 1    Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2    @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3    @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# 4    Bom dia meu amigo Humber tô Costa eu não conco...      Lula
# ..                                                 ...       ...
# 148  @cirogomes @CartunistaT E vc é o mestre dos ma...      Ciro
# 149  @VanAzevedo1 @BrazilFight Ele é  louco. Jaja e...      Ciro
# 150  @renato_abreu88 @cirogomes Pra gente não faz d...      Ciro
# 151  @cirogomes @CartunistaT Se eu fosse cirista eu...      Ciro
# 152  Impossível discordar de Ciro Gomes nessa. Infe...      Ciro
#
#                                            Tweet_limpo  \
# 0    ganni lula women's red patent leather slip on ...
# 1    bom para todos eleitores do lula🌹“que a felici...
# 2                               avisa a miriam leitão
# 3     datafolha: 100% dos brasileiros acreditam que...
# 4    bom dia meu amigo humber tô costa eu não conco...
# ..                                                 ...
# 148    e vc é o mestre dos magos, que não queria de...
# 149    ele é  louco. jaja elogia o pinguço.  tudo d...
# 150    pra gente não faz diferença!! estamos só esp...
# 151    se eu fosse cirista eu já tinha me enterrado...
# 152  impossível discordar de ciro gomes nessa. infe...
#
#                                            Sentimentos  Positivo  Neutro  \
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 1    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 4    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# ..                                                 ...       ...     ...
# 148  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 149  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 150  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 151  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
# 152  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0     1.0
#
#      Negativo  Composição Resultado_Sentimento
# 0         0.0         0.0             Negativo
# 1         0.0         0.0             Negativo
# 2         0.0         0.0             Negativo
# 3         0.0         0.0             Negativo
# 4         0.0         0.0             Negativo
# ..        ...         ...                  ...
# 148       0.0         0.0             Negativo
# 149       0.0         0.0             Negativo
# 150       0.0         0.0             Negativo
# 151       0.0         0.0             Negativo
# 152       0.0         0.0             Negativo
#
# [153 rows x 11 columns]

# %%
df_sentimento.loc[df_sentimento['Resultado_Sentimento'] == 'Positivo']
# Out:
#                      Data_Hora              IdTweet  \
# 24   2022-08-01 12:14:54+00:00  1554078213172781056
# 76   2022-08-01 12:20:54+00:00  1554079723747155971
# 94   2022-08-01 12:20:29+00:00  1554079621406199809
# 111  2022-08-01 12:20:31+00:00  1554079627873845249
# 115  2022-08-01 12:19:53+00:00  1554079470889435140
# 120  2022-08-01 12:19:25+00:00  1554079351959949312
# 147  2022-08-01 12:16:37+00:00  1554078648826843136
#
#                                                  Tweet  Candidato  \
# 24   Bom dia, geral . \nHoje é dia de compartilhar,...       Lula
# 76   @Kim_Galo1989 @RomeuZema Ok. O Temer decidiu. ...  Bolsonaro
# 94   @jairbolsonaro É isso ai meu Presidente, quand...  Bolsonaro
# 111  @cirogomes @CartunistaT O mais legal é ver os ...       Ciro
# 115  @camarq @cirogomes na Amazon tem.. https://t.c...       Ciro
# 120  @cirogomes @Debinha7 @CopaAmerica 🇧🇷✊😀🌹 #CiroP...       Ciro
# 147  @oBarbudinho @cirogomes "Muito bom seu stand u...       Ciro
#
#                                            Tweet_limpo  \
# 24   bom dia, geral . hoje é dia de compartilhar, c...
# 76     ok. o temer decidiu. o bolsonaro decidiu man...
# 94    é isso ai meu presidente, quando que entra em...
# 111    o mais legal é ver os petistas latindo nos c...
# 115                                   na amazon tem..
# 120     🇧🇷✊😀🌹  pra reindustrializar e empregar (&gt...
# 147                    "muito bom seu stand up comedy"
#
#                                            Sentimentos  Positivo  Neutro  \
# 24   {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'comp...     0.041   0.959
# 76   {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'comp...     0.216   0.784
# 94   {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...     0.110   0.890
# 111  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...     0.143   0.857
# 115  {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'comp...     0.459   0.541
# 120  {'neg': 0.0, 'neu': 0.388, 'pos': 0.612, 'comp...     0.612   0.388
# 147  {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'comp...     0.333   0.667
#
#      Negativo  Composição Resultado_Sentimento
# 24        0.0      0.1280             Positivo
# 76        0.0      0.2960             Positivo
# 94        0.0      0.2732             Positivo
# 111       0.0      0.1280             Positivo
# 115       0.0      0.1779             Positivo
# 120       0.0      0.6486             Positivo
# 147       0.0      0.3612             Positivo

# %% [markdown]
# Exportando

# %%
df_sentimento.to_csv('Etapa 4.csv', sep=',', index=False)
