# %% [markdown]
# <a href="https://colab.research.google.com/github/CaioEMBDS/DataTwitter_Eleitoral/blob/main/Etapa_2_Coleta_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Apresentação do projeto
# ---
# Proposta para a construção de uma aplicação ue realiza análise de sentimento dos candidatos à presidência

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Importando as bibliotecas

# %%
import snscrape.modules.twitter as sntwitter

#Manipulação de Dados
import pandas as pd

# %%
maximo_de_tweets = 50 #número máximo de tweets que queremos pegar

# %%
lista_de_tweets_lula = []
lista_de_tweets_bolsonaro = []
lista_de_tweets_ciro = []

# %% [markdown]
# Estrutura do scraper

# %%
sntwitter.TwitterSearchScraper()

# %% [markdown]
# Preciamos usar um for para percorrer várias vezes
#
# vamos precisar de:
# >alguém controlando so 50 tweets(i);
#
# >alguém salvando os textos(tweet)
#
# Usaremos o *enumerate*, pois condensa duas variáveis em um único assunto (no caso i e tweet dentro do range de sntwitter.TwitterSearchScraper())
#
# Usaremos o .get_items também para analisar variações do mesmo termo

# %% [markdown]
# ##Lula

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['Lula']).get_items()):
  if i > maximo_de_tweets:
    break #se i ultrapassar os 50, ele para o loop for
  lista_de_tweets_lula.append([tweet.date, tweet.id, tweet.content]) #vamos listar a data, o id de usuário e o conteúdo do tweet

# %%
lista_de_tweets_lula
# Out:
# [[datetime.datetime(2022, 8, 1, 12, 15, 12, tzinfo=datetime.timezone.utc),
#   1554078292004577283,
#   "Ganni Lula Women's red patent leather slip on flat dress pump shoes size EUR 37 https://t.co/94U3fqcPiL eBay https://t.co/jibeOIaQuE"],
#  [datetime.datetime(2022, 8, 1, 12, 15, 12, tzinfo=datetime.timezone.utc),
#   1554078289316253697,
#   'Bom para todos eleitores do Lula🌹\n“Que a felicidade vire rotina.”\n#lulaeleitonoprimeiroturno'],
#  [datetime.datetime(2022, 8, 1, 12, 15, 12, tzinfo=datetime.timezone.utc),
#   1554078289148493824,
#   '@alexandrekalil @LulaOficial Avisa a Miriam leitão https://t.co/WODBpMxt0d'],
#  [datetime.datetime(2022, 8, 1, 12, 15, 10, tzinfo=datetime.timezone.utc),
#   1554078280223006726,
#   '@guimaraes13PT Datafolha: 100% dos brasileiros acreditam que Lula é inocente'],
#  [datetime.datetime(2022, 8, 1, 12, 15, 8, tzinfo=datetime.timezone.utc),
#   1554078275269529602,
# ...

# %% [markdown]
# Melhorando a Estrutura com a função .DataFrame() do Pandas

# %%
dataframe_tweets_lula = pd.DataFrame(data=lista_de_tweets_lula, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:15:12+00:00  1554078292004577283
# 1 2022-08-01 12:15:12+00:00  1554078289316253697
# 2 2022-08-01 12:15:12+00:00  1554078289148493824
# 3 2022-08-01 12:15:10+00:00  1554078280223006726
# 4 2022-08-01 12:15:08+00:00  1554078275269529602
#
#                                                Tweet
# 0  Ganni Lula Women's red patent leather slip on ...
# 1  Bom para todos eleitores do Lula🌹\n“Que a feli...
# 2  @alexandrekalil @LulaOficial Avisa a Miriam le...
# 3  @guimaraes13PT Datafolha: 100% dos brasileiros...
# 4  Bom dia meu amigo Humber tô Costa eu não conco...

# %%
dataframe_tweets_lula['Candidato'] = 'Lula'

# %%
dataframe_tweets_lula.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:15:12+00:00  1554078292004577283
# 1 2022-08-01 12:15:12+00:00  1554078289316253697
# 2 2022-08-01 12:15:12+00:00  1554078289148493824
# 3 2022-08-01 12:15:10+00:00  1554078280223006726
# 4 2022-08-01 12:15:08+00:00  1554078275269529602
#
#                                                Tweet Candidato
# 0  Ganni Lula Women's red patent leather slip on ...      Lula
# 1  Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2  @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3  @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# 4  Bom dia meu amigo Humber tô Costa eu não conco...      Lula

# %% [markdown]
# ##Bolsonaro

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['Bolsonaro']).get_items()):
  if i > maximo_de_tweets:
    break 
  lista_de_tweets_bolsonaro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_bolsonaro = pd.DataFrame(data=lista_de_tweets_bolsonaro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:21:17+00:00  1554079820648267776
# 1 2022-08-01 12:21:16+00:00  1554079817435430912
# 2 2022-08-01 12:21:15+00:00  1554079814440681472
# 3 2022-08-01 12:21:15+00:00  1554079812846850051
# 4 2022-08-01 12:21:15+00:00  1554079811689226240
#
#                                                Tweet
# 0                          @MRAzeved Bolsonaro claro
# 1  É um 10. Mas defende o Bolsonaro no meio do ro...
# 2  @NNetocolto @brasil247 ⬆️Vai sim 15 dias foi m...
# 3  @LulaOficial Lula hipócrita, você já teve sua ...
# 4  @carteiroreaca @jairbolsonaro @BolsonaroSP @ta...

# %%
dataframe_tweets_bolsonaro['Candidato'] = 'Bolsonaro'

# %%
dataframe_tweets_bolsonaro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:21:17+00:00  1554079820648267776
# 1 2022-08-01 12:21:16+00:00  1554079817435430912
# 2 2022-08-01 12:21:15+00:00  1554079814440681472
# 3 2022-08-01 12:21:15+00:00  1554079812846850051
# 4 2022-08-01 12:21:15+00:00  1554079811689226240
#
#                                                Tweet  Candidato
# 0                          @MRAzeved Bolsonaro claro  Bolsonaro
# 1  É um 10. Mas defende o Bolsonaro no meio do ro...  Bolsonaro
# 2  @NNetocolto @brasil247 ⬆️Vai sim 15 dias foi m...  Bolsonaro
# 3  @LulaOficial Lula hipócrita, você já teve sua ...  Bolsonaro
# 4  @carteiroreaca @jairbolsonaro @BolsonaroSP @ta...  Bolsonaro

# %% [markdown]
# ##Ciro

# %%
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(['Ciro Gomes']).get_items()):
  if i > maximo_de_tweets:
    break 
  lista_de_tweets_ciro.append([tweet.date, tweet.id, tweet.content])

# %%
dataframe_tweets_ciro = pd.DataFrame(data=lista_de_tweets_ciro, columns=['Data_Hora', 'IdTweet', 'Tweet'])

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:21:03+00:00  1554079760912994304
# 1 2022-08-01 12:21:01+00:00  1554079754881466369
# 2 2022-08-01 12:20:57+00:00  1554079738980884481
# 3 2022-08-01 12:20:57+00:00  1554079736246243330
# 4 2022-08-01 12:20:54+00:00  1554079723311042561
#
#                                                Tweet
# 0                         @cirogomes #CiroPresidente
# 1  @renanetc @cirogomes Cada um escolhe o candida...
# 2  Ciro Gomes explicou para o Valor como vai ser ...
# 3  @elzamariana Vou de #CiroPresidente #CiroNoSeg...
# 4  @gisasouzza @cirogomes Não jogue sujo você! Co...

# %%
dataframe_tweets_ciro['Candidato'] = 'Ciro'

# %%
dataframe_tweets_ciro.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:21:03+00:00  1554079760912994304
# 1 2022-08-01 12:21:01+00:00  1554079754881466369
# 2 2022-08-01 12:20:57+00:00  1554079738980884481
# 3 2022-08-01 12:20:57+00:00  1554079736246243330
# 4 2022-08-01 12:20:54+00:00  1554079723311042561
#
#                                                Tweet Candidato
# 0                         @cirogomes #CiroPresidente      Ciro
# 1  @renanetc @cirogomes Cada um escolhe o candida...      Ciro
# 2  Ciro Gomes explicou para o Valor como vai ser ...      Ciro
# 3  @elzamariana Vou de #CiroPresidente #CiroNoSeg...      Ciro
# 4  @gisasouzza @cirogomes Não jogue sujo você! Co...      Ciro

# %% [markdown]
# ##Concatenando os 3 dataframes
# ---
# Usando o pandas.concat()
# >no nosso caso, pd.concat()

# %%
#Aqui vai abrigar os 3 dataframes criados que serão concatenados 
objs = [dataframe_tweets_lula, dataframe_tweets_bolsonaro, dataframe_tweets_ciro]

# %%
lista_completa = pd.concat(objs, axis=0, join='outer',
                           ignore_index=False, copy=True)

# %% [markdown]
# Umpouco sobre os parâmetros:
# > objs -> lista de dataframes que serão usados
#
# > axis= -> o valor pode ser 0 (para organizar do jeito que eu fiz), ou 1 (para orgaizar por linhas, e não colunas)
#
# > join= -> valor em string que vale 'inner' ou, como de padrão 'outer'.
# >>inner -> juntar somente a interceção dos valores
#
# >>outer -> junta tudo que não é inteceção
#
# >ignore_index= -> valor booleano. Cria um index
#
# >copy= -> cria uma cópia e concatena. Não afeta os originais

# %%
lista_completa.head()
# Out:
#                   Data_Hora              IdTweet  \
# 0 2022-08-01 12:15:12+00:00  1554078292004577283
# 1 2022-08-01 12:15:12+00:00  1554078289316253697
# 2 2022-08-01 12:15:12+00:00  1554078289148493824
# 3 2022-08-01 12:15:10+00:00  1554078280223006726
# 4 2022-08-01 12:15:08+00:00  1554078275269529602
#
#                                                Tweet Candidato
# 0  Ganni Lula Women's red patent leather slip on ...      Lula
# 1  Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2  @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3  @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# 4  Bom dia meu amigo Humber tô Costa eu não conco...      Lula

# %%
lista_completa.tail()
# Out:
#                    Data_Hora              IdTweet  \
# 46 2022-08-01 12:16:35+00:00  1554078640173993984
# 47 2022-08-01 12:16:34+00:00  1554078633110786049
# 48 2022-08-01 12:16:33+00:00  1554078631391010824
# 49 2022-08-01 12:16:26+00:00  1554078599447298049
# 50 2022-08-01 12:16:13+00:00  1554078545944760320
#
#                                                 Tweet Candidato
# 46  @cirogomes @CartunistaT E vc é o mestre dos ma...      Ciro
# 47  @VanAzevedo1 @BrazilFight Ele é  louco. Jaja e...      Ciro
# 48  @renato_abreu88 @cirogomes Pra gente não faz d...      Ciro
# 49  @cirogomes @CartunistaT Se eu fosse cirista eu...      Ciro
# 50  Impossível discordar de Ciro Gomes nessa. Infe...      Ciro

# %%
lista_completa.loc[lista_completa['Candidato'] == 'Bolsonaro']
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-08-01 12:21:17+00:00  1554079820648267776
# 1  2022-08-01 12:21:16+00:00  1554079817435430912
# 2  2022-08-01 12:21:15+00:00  1554079814440681472
# 3  2022-08-01 12:21:15+00:00  1554079812846850051
# 4  2022-08-01 12:21:15+00:00  1554079811689226240
# 5  2022-08-01 12:21:14+00:00  1554079810690883584
# 6  2022-08-01 12:21:14+00:00  1554079807788523520
# 7  2022-08-01 12:21:13+00:00  1554079805909487616
# 8  2022-08-01 12:21:11+00:00  1554079798074417157
# 9  2022-08-01 12:21:11+00:00  1554079795205505024
# 10 2022-08-01 12:21:11+00:00  1554079794807054337
# 11 2022-08-01 12:21:11+00:00  1554079794635186177
# 12 2022-08-01 12:21:10+00:00  1554079793095794688
# 13 2022-08-01 12:21:08+00:00  1554079782794584065
# 14 2022-08-01 12:21:08+00:00  1554079781683093506
# 15 2022-08-01 12:21:07+00:00  1554079780718497793
# 16 2022-08-01 12:21:05+00:00  1554079771356692480
# 17 2022-08-01 12:21:05+00:00  1554079771331534848
# ...

# %%
lista_completa
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-08-01 12:15:12+00:00  1554078292004577283
# 1  2022-08-01 12:15:12+00:00  1554078289316253697
# 2  2022-08-01 12:15:12+00:00  1554078289148493824
# 3  2022-08-01 12:15:10+00:00  1554078280223006726
# 4  2022-08-01 12:15:08+00:00  1554078275269529602
# ..                       ...                  ...
# 46 2022-08-01 12:16:35+00:00  1554078640173993984
# 47 2022-08-01 12:16:34+00:00  1554078633110786049
# 48 2022-08-01 12:16:33+00:00  1554078631391010824
# 49 2022-08-01 12:16:26+00:00  1554078599447298049
# 50 2022-08-01 12:16:13+00:00  1554078545944760320
#
#                                                 Tweet Candidato
# 0   Ganni Lula Women's red patent leather slip on ...      Lula
# 1   Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2   @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3   @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# ...

# %% [markdown]
# ##Savando como arquivo externo
# ---
# Usando pd.to_csv()

# %%
lista_completa.to_csv('dataframe_final_candidatos.csv',sep=',', index=False)

# %%
df = pd.read_csv('/content/dataframe_final_candidatos.csv')

# %%
df
# Out:
#                      Data_Hora              IdTweet  \
# 0    2022-08-01 12:15:12+00:00  1554078292004577283
# 1    2022-08-01 12:15:12+00:00  1554078289316253697
# 2    2022-08-01 12:15:12+00:00  1554078289148493824
# 3    2022-08-01 12:15:10+00:00  1554078280223006726
# 4    2022-08-01 12:15:08+00:00  1554078275269529602
# ..                         ...                  ...
# 148  2022-08-01 12:16:35+00:00  1554078640173993984
# 149  2022-08-01 12:16:34+00:00  1554078633110786049
# 150  2022-08-01 12:16:33+00:00  1554078631391010824
# 151  2022-08-01 12:16:26+00:00  1554078599447298049
# 152  2022-08-01 12:16:13+00:00  1554078545944760320
#
#                                                  Tweet Candidato
# 0    Ganni Lula Women's red patent leather slip on ...      Lula
# 1    Bom para todos eleitores do Lula🌹\n“Que a feli...      Lula
# 2    @alexandrekalil @LulaOficial Avisa a Miriam le...      Lula
# 3    @guimaraes13PT Datafolha: 100% dos brasileiros...      Lula
# ...
